# %%
import requests

# %%
riotApi = 'RGAPI-839c783f-7df0-462c-8b80-1c7ea25cf990'

# %%
url = f'https://kr.api.riotgames.com/lol/league/v4/challengerleagues/by-queue/RANKED_SOLO_5x5?api_key={riotApi}'

# %%
res = requests.get(url).json()

# %%
res.keys()
# Out:
# dict_keys(['tier', 'leagueId', 'queue', 'name', 'entries'])

# %%
res['tier']
# Out:
# 'CHALLENGER'

# %%
res['leagueId']
# Out:
# '966df365-7dea-34ca-839a-2cec050ba64a'

# %%
res['queue']
# Out:
# 'RANKED_SOLO_5x5'

# %%
res['name']
# Out:
# "Nami's Alliance"

# %%
res['entries'][0]
# Out:
# {'summonerId': 'bLGNh2YuJKY7c590zqN_tVAl1YiRqPlCTn0C-e9HfCON2oo',
#  'summonerName': '호잇이',
#  'leaguePoints': 985,
#  'rank': 'I',
#  'wins': 193,
#  'losses': 144,
#  'veteran': False,
#  'inactive': False,
#  'freshBlood': False,
#  'hotStreak': False}

# %%
lst = [res['entries'][i]['summonerId'] for i in range(len(res['entries']))]

# %%
lst
# Out:
# ['bLGNh2YuJKY7c590zqN_tVAl1YiRqPlCTn0C-e9HfCON2oo',
#  '8AWzXmarqFxiIvs1Mhj_vck_YaS_Itlqn7DnV7Eeb4dAT9Ts',
#  'vVr9T8tk6fx9bDvgpzhOhoYX4VxtCajRX0A2732vs102xbY',
#  'd5J4q8gRXC9YCQGTCgqJIfA4zsLFnuUp8M-qKi107uqndY5-',
#  'za2v_M1sDFTn3nMXFZ844l7hUPh3WbMPnVQVVlI4RFADMZE',
#  'dHlvn2FgR65da1C5_-IVJ6G5wESyhDYKyazR4WEKZbTEREI',
#  'jZdmRSLf9PF5fAj8OHGiBCMm971-Hf3MJP4NwPBChOnUEKk',
#  'EiAh0zongFuAfY86D_KhgqT_1XKAoAbkzg1shIP9FlzTrFSk',
#  'x6byVmb2kiCzEIcOTMeJeBiaOTxevr85Uyd9UmbFn6N5DdM',
#  'b3JeXt9gHf3VJ0WF33ElHBkT_TXnYrBQ1Z70dmlIyff1Hgs',
#  '2gQLpb0AzqO3VBVuycMYiyK3VvXgwue5mmivQqNIi8WGBnA',
#  '2YM_fetxbIbgvKMi9Ly0pttDsd-eZa-PK_fwmfiNJjIYAVPM',
#  'q8TKCmE4WyETus5LAOT1cvQRrFQ-v2ipNg2LhCqHC5Nozkw',
#  'Y-xTFNUgSbF2U3GhQDyt2RYS9fC7_bEvjGwoABZxpmiN47Nrt0vad4SqGA',
#  '8tSMcYFOiodEd8Dhw9l8w-rfjotWUavFuREG3LLgdZ035w',
#  'yaPfKqpvoQe48Jg9DHg1uVZ_7ekKSGwN7V3t6jaeSLLUSHs',
#  'PgdCOE_WGg0HQaCNwo93NMEjEWbSbVbUYUmPv7_a4GVgT8FCi4ZLtOYiNA',
#  'zzz-oLzs3eEcJAN316gn4JH8iraxKfVGdrqUI8aMTHjvI_U',
# ...

# %%
summonerId = lst[0]

# %%
url2 = f'https://kr.api.riotgames.com/lol/summoner/v4/summoners/{summonerId}?api_key={riotApi}'

# %%
res2 = requests.get(url2).json()

# %%
puuid = res2['puuid']

# %%
puuid
# Out:
# 'HwlJKlvXGzEX2RViz7xlYbGRV9LX36Wu5S-09PHW-8vZ-XorTx6Oqve8rJfOUHyE5Z5wzmaCS2KRSw'

# %%
url3 = f'https://asia.api.riotgames.com/lol/match/v5/matches/KR_6850466089/timeline?api_key={riotApi}'

# %%
url4 = f'https://asia.api.riotgames.com/lol/match/v5/matches/KR_6823337832?api_key={riotApi}'

# %%
res3 = requests.get(url3,url4).json()

# %%
res3
# Out:
# {'metadata': {'dataVersion': '2',
#   'matchId': 'KR_6850466089',
#   'participants': ['TyjSwQKEMeNuKFh-saRDbeEzDbf3svZCsZqKFJqGQfpKa_KkExBH1B7W8T7YjVInng8WHW_6I3zdxQ',
#    'yhjgTf5SSJGwkgeGDjv5nFl2aRstpxtFPfuFblMI0p6cAc8H3A1nQE96OEEPJSwP0-3av5WdkOquOg',
#    'bxp4vd4_M_ONUWjo41sKYrJkwzagmZvaFiIg8SEGOS2udDYh8op5pjWWzHoeA-XH7C29Vqo1DtzKiQ',
#    'EHODrEXclNMFeQLhD1z4tIC1dV9ahttamwtH4ipuhozxl-pRqdrKPqyUGZyAXy3U5zevsKc4GVB9Eg',
#    'PHAzqUxbfwD7sXzuiPYJwjHzovr_LwSJJd8CspuuOoXYZhY90-L2kbf1mGwSH88tbSjdJJY1HE9qIg',
#    'CheDPXWo2hCvhaXYxP7dIv1iLlxZt2SovHR7K9WHJ2nSEyp5SITd4mjIFE8-C9VdJcLc8a-2X6Mifg',
#    'aKb448PIm3if4PhToNaNt8zgFG65VVX2bsaSI71ncRpotjBzOqC1I5nod7_xJxNyz74NtH7b5Y7uZg',
#    'CeIHUPx_ABXoWpCQb7T8DTDZjZcrNgSrahbsTURIZ00uFEJIDy0iVY1KmqeffoQh2xksvODjr2N8Kg',
#    'Yrdir_vZfK7ozTAb7KCUOiLPCUz6aApiYiC_pPzuMtt1XwMAcuvCwVsWHkXHEk_W30EYoyiVxDGVrw',
#    'pcPswfux5BWnwvkYHnmqH8QDyQIZR2M_6JMKsZoUgqGZeJ3p4-KX6FuwXqmvUAcDTWq-OqB2OrSCSw']},
#  'info': {'frameInterval': 60000,
# ...

# %%
res3['info']['frames']
# Out:
# [{'events': [{'realTimestamp': 1702636062563,
#     'timestamp': 0,
#     'type': 'PAUSE_END'}],
#   'participantFrames': {'1': {'championStats': {'abilityHaste': 0,
#      'abilityPower': 0,
#      'armor': 27,
#      'armorPen': 0,
#      'armorPenPercent': 0,
#      'attackDamage': 25,
#      'attackSpeed': 100,
#      'bonusArmorPenPercent': 0,
#      'bonusMagicPenPercent': 0,
#      'ccReduction': 0,
#      'cooldownReduction': 0,
#      'health': 607,
#      'healthMax': 607,
#      'healthRegen': 0,
#      'lifesteal': 0,
#      'magicPen': 0,
#      'magicPenPercent': 0,
#      'magicResist': 30,
#      'movementSpeed': 330,
#      'omnivamp': 0,
#      'physicalVamp': 0,
#      'power': 0,
#      'powerMax': 2,
#      'powerRegen': 0,
#      'spellVamp': 0},
#     'currentGold': 500,
#     'damageStats': {'magicDamageDone': 0,
#      'magicDamageDoneToChampions': 0,
#      'magicDamageTaken': 0,
#      'physicalDamageDone': 0,
#      'physicalDamageDoneToChampions': 0,
# ...

# %%
def get_puuid(nickname,tag):
    url0 =f'https://asia.api.riotgames.com/riot/account/v1/accounts/by-riot-id/{nickname}/{tag}?api_key={riotApi}'
    res0 = requests.get(url0).json()
    puuid = res2['puuid']
    return puuid

# %%
def get_match_id(puuid):
    url9 = f'https://asia.api.riotgames.com/lol/match/v5/matches/by-puuid/{puuid}/ids?count=1&api_key={riotApi}'
    res9 = requests.get(url9).json()
    match_id = res9
    return match_id

# %%
def get_matches_timelines(match_id):
    url10 = f'https://asia.api.riotgames.com/lol/match/v5/matches/{match_id}?api_key={riotApi}'
    url11 = f'https://asia.api.riotgames.com/lol/match/v5/matches/{match_id}/timeline?api_key={riotApi}'
    res10 = requests.get(url10).json()
    res11 = requests.get(url11).json()
    matches = res10
    timelines = res11
    return matches,timelines

# %%
get_puuid('Hide%20on%20bush','KR1')
# Out:
# 'HwlJKlvXGzEX2RViz7xlYbGRV9LX36Wu5S-09PHW-8vZ-XorTx6Oqve8rJfOUHyE5Z5wzmaCS2KRSw'

# %%
get_match_id('CeIHUPx_ABXoWpCQb7T8DTDZjZcrNgSrahbsTURIZ00uFEJIDy0iVY1KmqeffoQh2xksvODjr2N8Kg')
# Out:
# ['KR_6859773725']

# %%
get_matches_timelines('KR_6850466089')
# Out:
# ({'metadata': {'dataVersion': '2',
#    'matchId': 'KR_6850466089',
#    'participants': ['TyjSwQKEMeNuKFh-saRDbeEzDbf3svZCsZqKFJqGQfpKa_KkExBH1B7W8T7YjVInng8WHW_6I3zdxQ',
#     'yhjgTf5SSJGwkgeGDjv5nFl2aRstpxtFPfuFblMI0p6cAc8H3A1nQE96OEEPJSwP0-3av5WdkOquOg',
#     'bxp4vd4_M_ONUWjo41sKYrJkwzagmZvaFiIg8SEGOS2udDYh8op5pjWWzHoeA-XH7C29Vqo1DtzKiQ',
#     'EHODrEXclNMFeQLhD1z4tIC1dV9ahttamwtH4ipuhozxl-pRqdrKPqyUGZyAXy3U5zevsKc4GVB9Eg',
#     'PHAzqUxbfwD7sXzuiPYJwjHzovr_LwSJJd8CspuuOoXYZhY90-L2kbf1mGwSH88tbSjdJJY1HE9qIg',
#     'CheDPXWo2hCvhaXYxP7dIv1iLlxZt2SovHR7K9WHJ2nSEyp5SITd4mjIFE8-C9VdJcLc8a-2X6Mifg',
#     'aKb448PIm3if4PhToNaNt8zgFG65VVX2bsaSI71ncRpotjBzOqC1I5nod7_xJxNyz74NtH7b5Y7uZg',
#     'CeIHUPx_ABXoWpCQb7T8DTDZjZcrNgSrahbsTURIZ00uFEJIDy0iVY1KmqeffoQh2xksvODjr2N8Kg',
#     'Yrdir_vZfK7ozTAb7KCUOiLPCUz6aApiYiC_pPzuMtt1XwMAcuvCwVsWHkXHEk_W30EYoyiVxDGVrw',
#     'pcPswfux5BWnwvkYHnmqH8QDyQIZR2M_6JMKsZoUgqGZeJ3p4-KX6FuwXqmvUAcDTWq-OqB2OrSCSw']},
# ...

# %%
url2 = f'https://kr.api.riotgames.com/lol/summoner/v4/summoners/igPKw1XDNjP4YV3H1ISJfK-TKy_H0nL0HdlXXmD0TlJeSw4?api_key={riotApi}'

# %%
res2 = requests.get(url2).json()

# %%
res2
# Out:
# {'id': 'igPKw1XDNjP4YV3H1ISJfK-TKy_H0nL0HdlXXmD0TlJeSw4',
#  'accountId': 'P3VYnLEBPlhFylmKUfRDy3Cuyhd_M_EVK-qrtd1MrX1zEpQ',
#  'puuid': 'HyCd9Wt7R4G4enN6RyUmp2hB5NiM7Ki7CL-xj8J8XamMl0dVSY7UVZkfssGWj427lo3qJD78y3pPiQ',
#  'name': '하준상',
#  'profileIconId': 6046,
#  'revisionDate': 1703151658774,
#  'summonerLevel': 445}

# %%
url3 = f'https://asia.api.riotgames.com/riot/account/v1/accounts/by-puuid/HyCd9Wt7R4G4enN6RyUmp2hB5NiM7Ki7CL-xj8J8XamMl0dVSY7UVZkfssGWj427lo3qJD78y3pPiQ?api_key={riotApi}'

# %%
res3 = requests.get(url3).json()

# %%
res3
# Out:
# {'puuid': 'HyCd9Wt7R4G4enN6RyUmp2hB5NiM7Ki7CL-xj8J8XamMl0dVSY7UVZkfssGWj427lo3qJD78y3pPiQ',
#  'gameName': '하준상',
#  'tagLine': 'KR1'}

# %%
url4 = f'https://asia.api.riotgames.com/riot/account/v1/accounts/by-riot-id/Hide%20on%20bush/KR1?api_key={riotApi}'

# %%
res4 = requests.get(url4).json()

# %%
res4
# Out:
# {'puuid': 'OmO2rlqsYJvncow_kpCTG3-WP1-4rtFBCKbf15tRd0QZMFOAY1CkLJdcNGbCQRu1uPgNZ4EyXfmGJQ',
#  'gameName': 'Hide on bush',
#  'tagLine': 'KR1'}

# %%
url5 = f'https://asia.api.riotgames.com/lol/match/v5/matches/by-puuid/OmO2rlqsYJvncow_kpCTG3-WP1-4rtFBCKbf15tRd0QZMFOAY1CkLJdcNGbCQRu1uPgNZ4EyXfmGJQ/ids?start=0&count=20&api_key=RGAPI-839c783f-7df0-462c-8b80-1c7ea25cf990'

# %%
res5 = requests.get(url5).json()

# %%
res5
# Out:
# ['KR_6862114657',
#  'KR_6862072758',
#  'KR_6862019211',
#  'KR_6861986150',
#  'KR_6861941572',
#  'KR_6857541971',
#  'KR_6857505793',
#  'KR_6857484360',
#  'KR_6857451632',
#  'KR_6857431030',
#  'KR_6857329446',
#  'KR_6857073273',
#  'KR_6857023189',
#  'KR_6856954148',
#  'KR_6856863759',
#  'KR_6856822840',
#  'KR_6823337832',
#  'KR_6823319067',
#  'KR_6823283319',
#  'KR_6823194977']

# %%
url6 = 'https://asia.api.riotgames.com/lol/match/v5/matches/KR_6823337832?api_key=RGAPI-839c783f-7df0-462c-8b80-1c7ea25cf990'

# %%
res6 = requests.get(url6).json()

# %%
res6.keys()
# Out:
# dict_keys(['metadata', 'info'])

# %%
res6['metadata']
# Out:
# {'dataVersion': '2',
#  'matchId': 'KR_6823337832',
#  'participants': ['JTg0ekRnoXAaC-3OOEdeVARTq_Y-Orq_45obVg4CPToEFRkLcqN0ERFlCEvxMz4pzDSzyuBOkB_Fpg',
#   'h2XO06ghXWR5O90Pby09hJhS36znT6KFgpvKPBrUH6AsLUkApf3qJnkU8v7CoUCAcJ91RM_p67tTiw',
#   'kZZFqpBC5T_xcM0GjyIpwZg3x1Jwa04rA2JtL5DSXQhDK-3i9Wy0dtqh8iCmKZZKDyPtP_Z9uHvcYQ',
#   'vCE_crff5C7B205z0TVpbcDYXGCML7ZikFznDq6eGZn8CN2aCk8RpwfDyVTWSTWh0EhPDJizfULZtA',
#   'Z_wrUJTLn20HznQa7KeECS-XJ9y_sqgbuh6n4VlrW3bffAqrcZn_rV-C6R6Olr3_bcyWNbBWuBcCMA',
#   'uPXvatDswUOBiewKjE4JtZyphmHj83MCOdCk3Y60SQ94NKk-bReQijpi5bBmy8Ubu1qVFfa4EqxXtw',
#   'BMoOaK2CYtS8IQv3haUdYK_5L4VJ2q6ledbbasFaYl53DT_d-raYwrWE8KrKAd6wwIrdJaKCUcXenw',
#   'OmO2rlqsYJvncow_kpCTG3-WP1-4rtFBCKbf15tRd0QZMFOAY1CkLJdcNGbCQRu1uPgNZ4EyXfmGJQ',
#   'nU9KxsGzhHBh_XYdqx43oaI06HXHe6IafdMLTQHD6I5EDcUeG55cXoUkrZXawjyy8HKtRI73II6CiA',
#   '0pCZIUoxvnX4TSekKPKjsCY3v3CCW1BZnqPN8DvSOUMbkuTuOw-KVNub8Lym-NuRz6EGZuLbhkk38w']}

# %%
res6['info'].keys()
# Out:
# dict_keys(['gameCreation', 'gameDuration', 'gameEndTimestamp', 'gameId', 'gameMode', 'gameName', 'gameStartTimestamp', 'gameType', 'gameVersion', 'mapId', 'participants', 'platformId', 'queueId', 'teams', 'tournamentCode'])

# %%
res6['info']['participants']
# Out:
# [{'allInPings': 0,
#   'assistMePings': 0,
#   'assists': 0,
#   'baitPings': 0,
#   'baronKills': 0,
#   'basicPings': 0,
#   'bountyLevel': 0,
#   'challenges': {'12AssistStreakCount': 0,
#    'abilityUses': 160,
#    'acesBefore15Minutes': 0,
#    'alliedJungleMonsterKills': 0,
#    'baronTakedowns': 0,
#    'blastConeOppositeOpponentCount': 0,
#    'bountyGold': 0,
#    'buffsStolen': 0,
#    'completeSupportQuestInTime': 0,
#    'controlWardTimeCoverageInRiverOrEnemyHalf': 0.37889466862900484,
#    'controlWardsPlaced': 2,
#    'damagePerMinute': 311.3595601997016,
#    'damageTakenOnTeamPercentage': 0.17737394539825307,
#    'dancedWithRiftHerald': 0,
#    'deathsByEnemyChamps': 4,
#    'dodgeSkillShotsSmallWindow': 0,
#    'doubleAces': 0,
#    'dragonTakedowns': 0,
#    'earlyLaningPhaseGoldExpAdvantage': 0,
#    'effectiveHealAndShielding': 0,
#    'elderDragonKillsWithOpposingSoul': 0,
#    'elderDragonMultikills': 0,
#    'enemyChampionImmobilizations': 6,
# ...

# %%
url7 = 'https://asia.api.riotgames.com/lol/match/v5/matches/KR_6823337832/timeline?api_key=RGAPI-839c783f-7df0-462c-8b80-1c7ea25cf990'

# %%
res7 = requests.get(url7).json()

# %%
res7['info']['frames'][10].keys()
# Out:
# dict_keys(['events', 'participantFrames', 'timestamp'])

# %%
import my_utills as mu

# %%
import requests

# %%
api_key = 'RGAPI-839c783f-7df0-462c-8b80-1c7ea25cf990'

# %%
puuid = mu.get_puuid('그래서뱀사안사','KR1')

# %%
matchlist = mu.get_match_id(puuid)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 matchlist = mu.get_match_id(puuid)
#
# TypeError: get_match_id() missing 1 required positional argument: 'num'

# %%
matches,timelines = mu.get_matches_timelines(matchlist[0])

# %%
url = f'https://kr.api.riotgames.com/lol/league/v4/entries/RANKED_SOLO_5x5/GOLD/IV?page=2&api_key={api_key}'

# %%
res = requests.get(url).json()

# %%
summonerId = res[0]['summonerId']

# %%
url2 = f'https://kr.api.riotgames.com/lol/summoner/v4/summoners/{summonerId}?api_key={api_key}'

# %%
res2 = requests.get(url2).json()

# %%
res2

# %%
import random
from tqdm import tqdm

# %%
def get_rawdata(tier) : 
    divisionList = ['I','II','III','IV']
    lst = []
    page = random.randrange(1,20)
    print('get summonerId....')
    for division in tqdm(divisionList) :
        url = f'https://kr.api.riotgames.com/lol/league/v4/entries/RANKED_SOLO_5x5/{tier}/{division}?page={page}&api_key={api_key}'
        res = requests.get(url).json()
        lst += random.sample(res,4)
    return lst

# %%
lst = get_rawdata('GOLD')

# %%
lst

# %%
def lst1():
    summonerIdList = []
    for i in lst :
        summonerIdList.append(i['summonerId'])
    return summonerIdList

# %%
summonerIdList = lst1()

# %%
summonerIdList

# %%
def get_puuid():
    puuidList = []
    summonerIdList = lst1()
    for summonerId in tqdm(summonerIdList):
        url2 = f'https://kr.api.riotgames.com/lol/summoner/v4/summoners/{summonerId}?api_key={api_key}'
        res2 = requests.get(url2).json()
        puuidList.append(res2['puuid'])
    return puuidList

# %%
puuidList = get_puuid()

# %%
def matchesId():
    matchIdList = []
    for puuid in tqdm(puuidList) :
        matchIdList += mu.get_match_id(puuid,3)
    return matchIdList

# %%
match_Id = matchesId()

# %%
match_Id

# %%
getList = []
for i in tqdm(range(len(matchId))) :
    matches, timelines = mu.get_matches_timelines(matchId[i])
    getList.append([matchId[i],matches,timelines])

# %%
df = pd.DataFrame(getList,columns=['matchid','matches','timelines'],)

# %%
import pandas as pd

# %%
df

# %%
df.iloc[0].matchid

# %%
import random
from tqdm import tqdm
import time
import my_utills as mu
from my_utills import *
import pandas as pd
import requests

# %%
api_key = 'RGAPI-839c783f-7df0-462c-8b80-1c7ea25cf990'

# %%
df = mu.get_rawdata('GOLD')  #raw데이터 가져오는함수
my_df = get_lol_data(df) # 데이터를 가공해서 전처리하는 함수
insert() # 데이터 전처리한걸 insert함수
time.sleep(60)
# Out:
# get summonerId....
#   0%|          | 0/4 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 df = mu.get_rawdata('GOLD')  #raw데이터 가져오는함수
#       2 my_df = get_lol_data(df) # 데이터를 가공해서 전처리하는 함수
#       3 insert() # 데이터 전처리한걸 insert함수
#
# File ~\my_utills.py:74, in get_rawdata(tier)
#      72     url = f'https://kr.api.riotgames.com/lol/league/v4/entries/RANKED_SOLO_5x5/{tier}/{division}?page={page}&api_key={api_key}'
#      73     res = requests.get(url).json()
# ---> 74     lst += random.sample(res, 3)
#      75 # lst라는 변수에서 summonerId만 리스트에 담기
#      76 summoner_id_list = list(map(lambda x: x['summonerId'], lst))
#
# File ~\anaconda3\Lib\random.py:439, in Random.sample(self, population, k, counts)
#     415 # Sampling without replacement entails tracking either potential
# ...

# %%
df = get_rawdata('GOLD')
# Out:
# get summonerId....
# 100%|██████████| 4/4 [00:03<00:00,  1.11it/s]
# get puuId.....
# 100%|██████████| 12/12 [00:10<00:00,  1.15it/s]
# get match_id....
# 100%|██████████| 12/12 [00:10<00:00,  1.14it/s]
# get matches & timeline....
# 100%|██████████| 36/36 [01:10<00:00,  1.95s/it]

# %%
def get_rawdata(tier):
    division_list = ['I','II','III','IV']
    lst = []
    page = random.randrange(1,20)
    print('get summonerId....')
    
    for division in tqdm(division_list):
        url = f'https://kr.api.riotgames.com/lol/league/v4/entries/RANKED_SOLO_5x5/{tier}/{division}?page={page}&api_key={api_key}'
        res = requests.get(url).json()
        lst += random.sample(res,3)
    # lst라는 변수에서 summonerId만 리스트에 담기
    summoner_id_list = list(map(lambda x:x['summonerId'] ,lst))
    # summonerId가 담긴 리스트를 통해 puuId
    print('get puuId.....')
    puu_id_list = []
    for summoner_id in tqdm(summoner_id_list):
        url = f'https://kr.api.riotgames.com/lol/summoner/v4/summoners/{summoner_id}?api_key={api_key}'
        res = requests.get(url).json()
        puu_id = res['puuid']
        puu_id_list.append(puu_id)
    
    print('get match_id....')
    match_id_list = []
    #puuId를 통해 matchId를 가져오기 -> 3개씩 담기
    for puu_id in tqdm(puu_id_list):
        match_ids = get_match_id(puu_id,3)
        match_id_list.extend(match_ids)
    print('get matches & timeline....')
    df_create = []
    for match_id in tqdm(match_id_list):
        matches,timelines = get_matches_timelines(match_id)
        df_create.append([match_id,matches,timelines])
    #matches,timeline을 불러서 이중리스트를 만들고 데이터프레임으로 만들어서 - [match_id,matches,timelines]
    df =pd.DataFrame(df_create,columns = ['match_id','matches','timelines'])
    return df

# %%
df
# Out:
#          match_id                                            matches  \
# 0   KR_6862316028  {'metadata': {'dataVersion': '2', 'matchId': '...
# 1   KR_6862289976  {'metadata': {'dataVersion': '2', 'matchId': '...
# 2   KR_6862289215  {'metadata': {'dataVersion': '2', 'matchId': '...
# 3   KR_6762326319  {'metadata': {'dataVersion': '2', 'matchId': '...
# 4   KR_6702425149  {'metadata': {'dataVersion': '2', 'matchId': '...
# 5   KR_6702361938  {'metadata': {'dataVersion': '2', 'matchId': '...
# 6   KR_6774917437  {'metadata': {'dataVersion': '2', 'matchId': '...
# 7   KR_6774796718  {'metadata': {'dataVersion': '2', 'matchId': '...
# 8   KR_6774748219  {'metadata': {'dataVersion': '2', 'matchId': '...
# 9   KR_6811188282  {'metadata': {'dataVersion': '2', 'matchId': '...
# 10  KR_6811161052  {'metadata': {'dataVersion': '2', 'matchId': '...
# 11  KR_6747927070  {'metadata': {'dataVersion': '2', 'matchId': '...
# 12  KR_6859175005  {'metadata': {'dataVersion': '2', 'matchId': '...
# ...

# %%
def lane_processing(tower_lane, tower_team, lane , team) :
    if (tower_lane[0] == lane[0]) and (tower_team == team) :
        return 1
    else :
        return 0

# %%
def assi_calc(x):
    try:
        return ','.join(list(map(lambda x : str(x), y['assistingParticipantIds'])))
    except:
        return ''

# %%
df_creates = []
for i in range(len(df)):
    try:
        match = df.iloc[i].matches['info']['participants']
        for j in range(len(match)):
            match_id = df.iloc[i].match_id
            game_duration = df.iloc[i].matches['info']['gameDuration']
            game_version = df.iloc[i].matches['info']['gameVersion']
            try:
                riotIdGameName = match[j]['riotIdGameName']
            except:
                riotIdGameName = ''
            try:
                riotIdTagline = match[j]['riotIdTagline']
            except:
                riotIdTagline = ''
            summoner_level = match[j]['summonerLevel']
            participants_id = match[j]['participantId']
            champion_name = match[j]['championName']
            champ_experience = match[j]['champExperience']
            team_position = match[j]['teamPosition']
            team_id = match[j]['teamId']
            win = match[j]['win']
            kills = match[j]['kills']
            deaths = match[j]['deaths']
            assists = match[j]['assists']
            total_damage_dealt = match[j]['totalDamageDealtToChampions']
            total_damage_taken = match[j]['totalDamageTaken']

            df_list = list(map(lambda x: x['events'],df.iloc[i].timelines['info']['frames']))
            event_list = [element for array in df_list for element in array]
            tower_log = list(filter(lambda x:x['type']=='BUILDING_KILL', event_list))
            try:
                ft_tower_lane = tower_log[0]['laneType']
                ft_tower_team = tower_log[0]['teamId']
            except:
                ft_tower_lane = 'n'
                ft_tower_team = 'n'
            ft = lane_processing(ft_tower_lane,ft_tower_team,team_position,team_id)

            tower_tmp = list(map(lambda x:(x['laneType'],x['teamId'],x['timestamp']),tower_log))
            try:
                laneTower = list(filter(lambda x:(x[0][0]==team_position[0]) & (x[1]==team_id), tower_tmp))[0]
                lane_flag = 1
                laneTowerTime = laneTower[-1]
            except:
                lane_flag = 0
                laneTowerTime = 0
                
            blue_ban = list(map(lambda x: str(x['championId']), df.iloc[i].matches['info']['teams'][0]['bans']))
            red_ban = list(map(lambda x: str(x['championId']), df.iloc[i].matches['info']['teams'][1]['bans']))
            ban_list = 'l'.join(list(set(blue_ban + red_ban)))

            kill_log = list(map(lambda x: list(filter(lambda z : z['type']=='CHAMPION_KILL',x['events'])) ,df.iloc[i].timelines['info']['frames']))
            kill_log = [element for array in kill_log for element in array]
            k = 'l'.join(list(map(lambda x: str(x['killerId']) ,kill_log)))
            v = 'l'.join(list(map(lambda x: str(x['victimId']), kill_log)))
            a = 'l'.join(list(map(lambda x: assi_calc(x), kill_log)))
            try:
                g15 = df.iloc[i].timelines['info']['frames'][15]['participantFrames'][(str(j+1))]['totalGold']
            except:
                g15 =0
        
            df_creates.append([match_id,game_duration,game_version,riotIdGameName,riotIdTagline,summoner_level,participants_id,
                              champion_name,champ_experience,team_position,team_id,win,kills,deaths,assists,total_damage_dealt,total_damage_taken,
                              ft,lane_flag,laneTowerTime,ban_list,k,v,a,g15])
    except:
        continue
columns =['matchId', 'gameDuration', 'gameVersion', 'riotIdGameName','riotIdTagline', 
           'summonerLevel', 'participantId', 'championName', 'champExperience', 
           'teamPosition', 'teamId', 'win', 'kills', 'deaths', 'assists', 'totalDamageDealtToChampions', 'totalDamageTaken',
         'firstDT','laneTower','LaneTowerTime','bans','killerId','victimId','assistId','G15']
df2 = pd.DataFrame(df_creates , columns = columns)

# %%
df2
# Out:
#            matchId  gameDuration     gameVersion riotIdGameName riotIdTagline  \
# 0    KR_6862316028          1812  13.24.547.9214       새주옹마늘경규줘         마늘경규줘
# 1    KR_6862316028          1812  13.24.547.9214         Cliche           KR3
# 2    KR_6862316028          1812  13.24.547.9214        0utcast           KR1
# 3    KR_6862316028          1812  13.24.547.9214            민초뚱           KR1
# 4    KR_6862316028          1812  13.24.547.9214   Hide on bush         REC01
# ..             ...           ...             ...            ...           ...
# 325  KR_6727491229          1926  13.19.533.1909
# 326  KR_6727491229          1926  13.19.533.1909
# 327  KR_6727491229          1926  13.19.533.1909
# 328  KR_6727491229          1926  13.19.533.1909
# 329  KR_6727491229          1926  13.19.533.1909
#
#      summonerLevel  participantId  championName  champExperience teamPosition  \
# 0              646              1          Sett            12968          TOP
# ...
